# %%
import pandas as pd

# %%
citi2018_06 = pd.read_csv("Citibike_data/cb-2018-06.csv.zip")
citi2018_07 = pd.read_csv("Citibike_data/cb-2018-07.csv.zip")
citi2018_08 = pd.read_csv("Citibike_data/cb-2018-08.csv.zip")
citi2018_09 = pd.read_csv("Citibike_data/cb-2018-09.csv.zip")
citi2018_10 = pd.read_csv("Citibike_data/cb-2018-10.csv.zip")
citi2018_11 = pd.read_csv("Citibike_data/cb-2018-11.csv.zip")
citi2018_12 = pd.read_csv("Citibike_data/cb-2018-12.csv.zip")
citi2019_01 = pd.read_csv("Citibike_data/cb-2019-01.csv.zip")
citi2019_02 = pd.read_csv("Citibike_data/cb-2019-02.csv.zip")
citi2019_03 = pd.read_csv("Citibike_data/cb-2019-03.csv.zip")
citi2019_04 = pd.read_csv("Citibike_data/cb-2019-04.csv.zip")
citi2019_05 = pd.read_csv("Citibike_data/cb-2019-05.csv.zip")
citi2019_06 = pd.read_csv("Citibike_data/cb-2019-06.csv.zip")

# %%
citi_data = [citi2018_06,
            citi2018_07,
            citi2018_08,
            citi2018_09,
            citi2018_10,
            citi2018_11,
            citi2018_12,
            citi2019_01,
            citi2019_02,
            citi2019_03,
            citi2019_04,
            citi2019_05,
            citi2019_06]
citi_totals = pd.concat(citi_data)
citi_totals
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               329  2018-06-01 07:07:00.2990  2018-06-01 07:12:30.2220
# 1               259  2018-06-01 08:24:43.8490  2018-06-01 08:29:03.8450
# 2               686  2018-06-01 09:17:49.5730  2018-06-01 09:29:16.1770
# 3               164  2018-06-01 09:44:00.4020  2018-06-01 09:46:44.6830
# 4               769  2018-06-01 09:59:28.7800  2018-06-01 10:12:18.6660
# ...             ...                       ...                       ...
# 39425           639  2019-06-30 23:38:29.5450  2019-06-30 23:49:09.2110
# 39426           643  2019-06-30 23:38:34.9100  2019-06-30 23:49:17.9690
# 39427           418  2019-06-30 23:42:30.9400  2019-06-30 23:49:29.5360
# 39428          2529  2019-06-30 23:46:17.5700  2019-07-01 00:28:27.1710
# 39429           831  2019-06-30 23:49:01.6830  2019-07-01 00:02:53.1150
#
#        start station id start station name  start station latitude  \
# ...

# %%
citi_totals.to_csv("Citibike_data/cb-totals.csv")
